# %%
x = 5
print(x)
for i in range(1,6):
    print(i)
# Out:
# 5
# 1
# 2
# 3
# 4
# 5

# %%
if x > 3:
    print("fun values:", x % -5)
# Out:
# fun values: 0

# %%
import math
print(math.ceil(3/2))
print(math.pow(3,4))
# Out:
# 2
# 81.0
