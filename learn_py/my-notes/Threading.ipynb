# %% [markdown]
# Multithreading in python
# allows multiple threads to run in parallel
#
# #Process --
# An execution program with prog code
# Data (variable, space , workspace)
# Execution context
#
# Thread is smallest unit of execution inside a process
# - Aprocess can have multi threads
# -
