# %%
class Animal:
    def eat(self):
        print("Animal eats!")

class Dog(Animal):
    def bark(self):
        print("Dog barks")
    pass
d1 = Dog()
print(d1.bark)
# Out:
# <bound method Dog.bark of <__main__.Dog object at 0x10a9a0440>>

# %%
class Animal:
    def __init__(self,name):
        self.name = name

    def display_animal(self):
        print("Animal name ",self.name)

class Dog(Animal):
    def __init__(self,name,breed):
        #super().__init__(self,name,breed)
        Animal.__init__(self,name)
        self.breed = breed

    def display_dog(self):
        print("Breed:", self.breed)

dog1 = Dog("Tommy","Golden Retriever")
dog1.display_animal()
dog1.display_dog()
# Out:
# Animal name  Tommy
# Breed: Golden Retriever

# %%
#Multiple inheritance
class Father:
    def gardening(self):
        print("Father knows gardening")
class Mother:
    def cooking(self):
        print("Mother knows cooking")
class Child(Father, Mother):
    def playing(self):
        print("Child is playing")

c = Child()
m = Mother()
c.cooking()
m.cooking()
c.playing()
# Out:
# Mother knows cooking
# Mother knows cooking
# Child is playing

# %%
class Father:
    def __init__(self,father_name):
        self.father_name = father_name
class Mother:
    def __init__(self,mother_name):
        self.mother_name = mother_name

class Child(Father, Mother):
    def __init__(self,father_name,mother_name,child_name):
        Father.__init__(self,father_name)
        Mother.__init__(self,mother_name)
        self.child_name = child_name

    def display(self):
        print(f"Father: {self.father_name} , Mother: {self.mother_name} for {self.child_name}")

c = Child("Fat_dad","Mot_mom", "Mr_son")
c.display()
# Out:
# Father: Fat_dad , Mother: Mot_mom for Mr_son
