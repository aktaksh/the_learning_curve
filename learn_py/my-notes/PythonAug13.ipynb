# %% [markdown]
# hashmap
# *args **kwargs --> uses in password
#
# def fun(**kwargs):
# for k,val in kwargs.items()
#     print(k.val)
#
#     *args.**kwargs = ("Math", "Science", Name : tom , Age : 20  )
#
#
# def show(name,age) ---> positional prameter and name age will be xtracted  with keyword args
# show(**data)

# %% [markdown]
# Decorator
#
#
# @decratorexample. --- it will pass the entire function return to decorator
# def mainfucntion():
#
# upper()
# slice()

# %% [markdown]
# Mist used --

# %% [markdown]
# text = "  OpenStack Cloud Server  "
# text.upper()                  # "  OPENSTACK CLOUD SERVER  "
# text.lower()                  # "  openstack cloud server  "
# text.strip()                  # "OpenStack Cloud Server"
# text.replace("Cloud", "VM")   # "  OpenStack VM Server  "
# text.split()                  # ["OpenStack", "Cloud", "Server"]
# "-".join(["web", "01"])       # "web-01"
#
# text.startswith("Open")       # False: spaces exist at beginning
# text.endswith("Server  ")     # True
# text.find("Cloud")            # 12: starting index
# text.count("e")               # 3
# "Cloud" in text               # True
#
# "123".isdigit()               # True
# "server".isalpha()            # True
# "server01".isalnum()          # True

# %% [markdown]
# name = "OpenStack"
#
# name[0]       # "O": first character
# name[-1]      # "k": last character
# name[0:4]     # "Open": index 0–3
# name[4:]      # "Stack": index 4 onward
# name[:4]      # "Open": beginning to index 3
# name[::2]     # "OeSak": every second character
# name[::-1]    # "kcatSnepO": reverse string
#
# 🔥 MOST IMPORTANT FOR LEETCODE
#
# • lower(), upper()       → normalize text
# • strip()                → remove outer spaces
# • split()                → string to list
# • join()                 → list to string
# • replace()              → replace characters
# • isalnum(), isdigit()   → validation
# • slicing [start:stop]   → extract sections
# • [::-1]                 → reverse
# • in                     → membership check
#
# # Common LeetCode pattern: clean and reverse
# text = "A man"
# cleaned = "".join(char.lower() for char in text if char.isalnum())
# reversed_text = cleaned[::-1]

# %% [markdown]
# def show(name, age):    print(name, age)data = {'name': 'Sam', 'age': 25}show(**data)

# %%
x = lamda a : a + 10. -- simple run
print(x(5))
# Out:
#   Cell In[4], line 1
#     x = lamda a : a + 10
#               ^
# SyntaxError: invalid syntax

# %%
number = [1,2,3]
def fume(x):
    return x * 2

ans = list(map(fume,number)) # Map passes function and list/tuple/ as arguments
print(ans)
# Out:
# [2, 4, 6]

# %%
number = [1,2,3]
it = (iter(number)) #container with multiple values
print(next(it))
print(next(it)) // Hum bache hai isliye

for i in number:
    print(i)
# Out:
# 1
# 2
# 1
# 2
# 3

# %%
# return will exit the function
# continue will not have any values
# generator with yield will have a value as output
#tuple = (1,2,3)

# list compprehensiton  --

# %% [markdown]
# __name__ == "__main__". >> run only when i directly execute this file
# __init__ runs when a newo bject is created
# __str__ decide what users will see when an object si created.
#
#
# class Server:
#     def __init__(self, name):
#         self.name = name
# server = ("server1").  --> then seld. name stores the  name in current container/object created
#
# class Server:
#     def __init__(current_object, name):  --- rename self to anything
#         current_object.name = name

# %%
class Server:
    def __init__(current_object, name):
        current_object.name = name
        print(current_object,hex(id(name)) )
        print(id(current_object))
server1 = Server("server01")
# Out:
# <__main__.Server object at 0x108176450> 0x10817fdb0
# 4430718032

# %%
class Server:
    def __init__(self, name):
        self.name = name

    def __str__(self):
        return self.name


server1 = Server("web01")

print(server1)  # web01
# Out:
# web01
