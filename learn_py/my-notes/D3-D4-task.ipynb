# %%
def calc():
    
    Q1 = int(input("Enter Quantity  for  item 1"))
    Q2 = int(input("Enter Quantity  for  item2 "))
    Q3 = int(input("Enter Quantity  for  item 3"))

    P1 = int(input("Enter Price for item 1"))
    P2 = int(input("Enter Price for item 2"))
    P3 = int(input("Enter Price for item 3"))
    print("Total cost:", P1 * Q1 + P2 * Q2 + P3 * Q3)
    
calc()
# Out:
# Total cost: 108

# %% [markdown]
# Mini Project: ATM Banking System
# Scenario
#
# Create a simple ATM program where the user enters their PIN. If the PIN is correct, show an ATM menu:
#
# 1. Check Balance
# 2. Withdraw Money
# 3. Deposit Money
# 4. Exit
#
# The program should perform different operations based on the user's choice.
#
# Rules
# Allow 3 PIN attempts.
# If the PIN is correct, show the menu.
# For withdrawal:
# Amount must be greater than 0.
# Amount must be a multiple of 500.
# Amount must not exceed the account balance.
# For deposit:
# Amount must be greater than 0.
# Display the updated balance after a successful transaction.
# '''

# %%
def login():
        i = 1
        while( i < 4):
            pin = int(input("Enter ATM PIN:"))
            if (pin == 1101 ):
                print("Successfully logged in, jump with happiness")
                options()
                break
            else:
                print("Incorrect PIN , Jog your memory ,Enter Pin Again :")
                i += 1
                continue
        

def options():
     print("1: check , 2: withdraw , 3: Deposit , 4: Logout")
     optn = int(input("Choose option:"))
     match optn:
        case 1: 
            balance()
        case 2: 
            withdraw()
        case 3: 
            deposit()
        case 4:
            break
               
          
amount = 990111333
    
def balance():
  print("You are rich bro", amount)
def withdraw():
    withamount = int(input("amount of withdrawl"))
    if (withamount > 0 and withamount % 500 == 0 ): 
        leftamount = amount - withamount 
        print("Successful. amount left", leftamount ) 
def deposit():
    pass


login()
# Out:
#   Cell In[21], line 26
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
balance = 2000
print(f"💰 Current balance: ${balance:,}")
print(f"Balance = ${balance:,}")
# Out:
# 💰 Current balance: $2,000
# Balance = $2,000
