# %% [markdown]
# '''
# 1) Create a dictionary containing student names as keys and a list of marks in 3 subjects as values. Find each student's total and average, display students with an average above 75, and find the student with the highest average.
#
# 2) Given a list of product names containing duplicates, create a set of unique products. Display the unique products, number of unique products, and products that appeared more than once.
#
# 3) Given three sets containing students from three different classes, find students common to all three classes, students present only in the first class, students present in exactly two classes, and the total number of unique students.
#
# 4) Take a sentence from the user and create a dictionary containing each word and its frequency. Display the most frequently occurring word and all words that occur more than once.
#
# 5) Create a dictionary representing a shopping cart where each product has a tuple containing quantity and price. Calculate the total cost of every product, the grand total, and apply a 10% discount if the total exceeds ₹50,000.
# '''

# %%
Romeo = {
        "math": 30,
        "phy": 23,
        "chem": 78
        }
print(Romeo.keys())
print(Romeo.values())
print(Romeo["math"])
print(Romeo.items())
#Romeo.update(["math",33])
print(Romeo["math"])
# Out:
# dict_keys(['math', 'phy', 'chem'])
# dict_values([30, 23, 78])
# 30
# dict_items([('math', 30), ('phy', 23), ('chem', 78)])
# 30

# %%
studlist = {
    "Romeo":{
        "math": 30,
        "phy": 23,
        "chem": 78
        },
    "Gongcha":{
        "math": 32,
        "phy": 53,
        "chem": 48
    }
}
print(studlist["Romeo".keys()])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 13
#       9         "phy": 53,
#      10         "chem": 48
#      11     }
#      12 }
# ---> 13 print(studlist["Romeo".keys()])
#
# AttributeError: 'str' object has no attribute 'keys'

# %%
[m for m in dir(dict) if not m.endswith('_')]
# Out:
# ['clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
help(dict.keys)
print(dict.keys.__doc__)
# Out:
# Help on method descriptor keys:
#
# keys(self, /) unbound builtins.dict method
#     Return a set-like object providing a view on the dict's keys.
#
# Return a set-like object providing a view on the dict's keys.

# %%
help(set.update)
# Out:
# Help on method descriptor update:
#
# update(self, /, *others) unbound builtins.set method
#     Update the set, adding elements from all others.

# %%
import random

# 1. Define the original dictionary
my_dict = {'apple': 1, 'banana': 2, 'cherry': 3, 'date': 4}

# 2. Select 2 unique random items and convert back to a dictionary
random_sample = dict(random.sample(list(my_dict.items()), 2))

# 3. Print the result
print(random_sample)
# Output example: {'cherry': 3, 'apple': 1}
# Out:
# {'banana': 2, 'date': 4}

# %%
s1 = {"Hello",34,1287.5,True,34,11,76,99,90,43}
s2 = {'HHH', 1111, 90, 'Hello',34,76,99,94}
#s.update(["HHH",1111, 2, 3 ,4, 66,66,78,66])
print(s1)



#s.discard(66)
#s.remove(78)
#s1 = s1.union(s2)
s1 = s1.__getstate__
print(s1)
# Out:
# {True, 34, 99, 1287.5, 11, 76, 43, 90, 'Hello'}
# <built-in method __getstate__ of set object at 0x10a6520a0>

# %%
studx = {
       "name": "tyler",
        "math": 24,
        "phy": 33,
        "allsubj": [23, 34, 67, 89],
    }

dicitem = studx.get("name")
'''
print(studx)
print(sum(studx.get("allsubj")))
print(studx.values())
'''
#print(studx.pop("math"))
#studx.popitem()
#studx.copy()
print(studx.fromkeys(studx))
# Out:
# {'name': None, 'math': None, 'phy': None, 'allsubj': None}

# %%
msg = "Josh is in hospitality"
for ind,char in enumerate(msg):
    print(ind,":",char)

# %%
msg = "Josh is in hospitality"
print(msg[:3:-1].upper().title().capitalize())
print(msg.count("o"))
print(msg.split(" "))
print(msg.ljust(3))
# Out:
# Ytilatipsoh ni si
# 2
# ['Josh', 'is', 'in', 'hospitality']
# Josh is in hospitality

# %%
pswd = "ThisisSecret123@#"
print(pswd.isalnum())
print(pswd.islower())
print(pswd.isupper())

for chr in pswd:
    if chr.isupper():
        continue
    else:
        break
    lflag = "green" if chr.islower() else "red"

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
# 1) Find the number of occurrence of a word inside a sentence without substring.
sentnc = "This is a world of challenges. World in this space can be tough"
slist = sentnc.lower().split()
duplicates = []
#print(slist)
for x,xwd in enumerate(slist):
    for y,ywd in enumerate(slist):
        if x != y and xwd == ywd:
            duplicates.append(xwd)
print(duplicates)


            


# loop for every word -- > x is the self index to loop
#   if word == another word excluding it's self index
#       increment the wordcount to +1
# Out:
# ['this', 'world', 'world', 'this']

# %%
passwd = "ThisisPsswd@"
for lt in passwd:
        if lt.isupper() :
            upp = True
            break
        if lt.islower():
            low = True
        if lt.isalnum():
             alnum = True 
        if lt == '#' or lt == '@':
              lt = True
        else:
             print("Not strong")

if upp and low and alnum and spl is True:
     print("Strong")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 15
#      11               lt = True
#      12         else:
#      13              print("Not strong")
#      14
# ---> 15 if upp and low and alnum and spl is True:
#      16      print("Strong")
#      17
#      18
#
# NameError: name 'spl' is not defined

# %%
passwd = "ThisisPsswd@"
for lt in passwd:
        if lt.isnumeric() :
            print(lt)
            break

# %%
help(any)
# Out:
# Help on built-in function any in module builtins:
#
# any(iterable, /)
#     Return True if bool(x) is True for any x in the iterable.
#
#     If the iterable is empty, return False.

# %% [markdown]
# 3) Mask sensitive data
# Given : 987676765487
# output: ********3210

# %%
given = 987676765487
result = []
strgiven = str(given)
for x,y in enumerate(strgiven[:-4]):
    print(x,y)
    result.append("*")
result.append(strgiven[-4:])
print("".join(result))
# Out:
# 0 9
# 1 8
# 2 7
# 3 6
# 4 7
# 5 6
# 6 7
# 7 6
# ********5487

# %%
given = 987676765487
result = []
strgiven = str(given)
strgiven.replace("6","0")
# Out:
# '987070705487'

# %%
help(str.replace)
# Out:
# Help on method descriptor replace:
#
# replace(self, old, new, /, count=-1) unbound builtins.str method
#     Return a copy with all occurrences of substring old replaced by new.
#
#       count
#         Maximum number of occurrences to replace.
#         -1 (the default value) means replace all occurrences.
#
#     If the optional argument count is given, only the first count occurrences are
#     replaced.
