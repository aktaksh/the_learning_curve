# %% [markdown]
# while is used when we do not know the interations.
# for is when you know the iterations.
#
# break runs - when a condition is satisfied
# for <-> else ---- another loop
#
# while -- else --
#
# #conitnue - Take back to the loop
# #pass -- just for future ciodes whenw e do not know what to use.
#
# Switch match ----
# subscreipt
# declare number = []  -- type datatype is class list
# When we use an image for number - numpy
# #case x if x>=90:
# #case 'r':
#
# for 1 in l1:
#     print(-1) -- from behind
# l1.append("")
# l1.index("")
# l1.insert(2,"Harry")
# l1.remove(78)
# Ternary operator
# l1.pop()
