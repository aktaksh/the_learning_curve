# %%
print('''hello''', end=' ')
print('''learner''')
# Out:
# hello learner

# %%
print(''' Hey there , I am Low laetency engineer''', end="...") # end and sep are arguments to modify the lines
print("I work to build cloud platform , profile is linux specialaist", end='@')
print('pvt-cloud', "On my way to learn the coding", sep="**")
print("Money defines my life", "Hence work hard" ,sep="--->", end="\t")
print("Taught by Shivangi"," Teacher", sep=">>")
# Out:
#  Hey there , I am Low laetency engineer...I work to build cloud platform , profile is linux specialaist@pvt-cloud**On my way to learn the coding
# Money defines my life--->Hence work hard	Taught by Shivangi>> Teacher

# %%
for i in range(2,9,2): # start,end, the increment
    print(i)
# Out:
# 2
# 4
# 6
# 8
