# %%
#1. Create a variable: salary = 50000, Increase the salary by 10% and print the new salary.

salary = 5000
salary *= 110
print(salary)

#2.Store the value 50 in a variable. Convert it into a float and divide it by 4.
x5 = 50
print(float(x5))

#3. Write a program to check whether two variables point to the same memory location.

if ((id(x5)) != (id(salary))):
    print((id(x5)) , (id(salary)) , "are diff locations")

#4. Create variables using multiple assignment. a = b = c = 100. Now modify only b.Print all variables.
a = b = c = 100
b += b
print("a,b,c new vals: ", a,b,c)

#5. Find the memory size occupied by each data type using sys. getsizeof ().

import sys
#5. Find the memory size occupied by each data type using sys. getsizeof ().
list1 = [1,4,67]
print("memory:",sys.getsizeof(list1))

#6. Take a person's age and calculate how many days they have lived (assume 365 days/year).
age = 0
print("Enter age in years fpr conevrsion:" )
#age = int(input())
days = age * 365
print("age in days:", days , age * 365)

#7. Convert total seconds into:
secs = 3675 % 60 
min = 3675 % 3660
hrs = 3675 // 3660



print("3675 as :", hrs, min, secs  )


#
# Out:
# 550000
# 50.0
# 4381108424 4499258160 are diff locations
# a,b,c new vals:  100 200 100
# memory: 88
# Enter age in years fpr conevrsion:
# age in days: 0 0
# 3675 as : 1 15 15

# %%
num1 = 9876
val = 0
while (num1 > 0):
        rem = num1 % 10 # val = 6
        num1 = num1 // 10
        val += rem
        print(rem,num1, val)


#get all vals -- for 9765 / 10 = 976  , 9765%10 = 5  --> when  97 , 6 --> 9 , 7 --> 1000 9 , if
# Out:
# 6 987 6
# 7 98 13
# 8 9 21
# 9 0 30

# %%
# scientific calc
print("Enter 2 nos , bigger no first")
input(a)
print("Enter 2nd no, smaller one")
input(b)
print("your nos:",a,b)
print("Summ:", a + b , "Mult:", a * b,"Div:", a / b, "Subtraction:", b - a , "Floor:", a // b, "Modulo:", a % b , "Exponent:", a ^ 5)
print("Square of 1st:", a * 2, "Cube 2nd:", b ** 3 , "Square root:", a ** 0.5 )
# Out:
# Enter 2 nos , bigger no first
# Enter 2nd no, smaller one
# your nos: 100 200
# Summ: 300 Mult: 20000 Div: 0.5 Subtraction: 100 Floor: 0 Modulo: 100 Exponent: 97
# Square of 1st: 200 Cube 2nd: 8000000 Square root: 10.0

# %%
9 % 10
# Out:
# 9

# %% [markdown]
# 1. Create a variable: salary = 50000, Increase the salary by 10% and print the new salary.
# 2.Store the value 50 in a variable. Convert it into a float and divide it by 4.
# 3. Write a program to check whether two variables point to the same memory location.
# 4. Create variables using multiple assignment. a = b = c = 100. Now modify only b.Print all variables.
# 5. Find the memory size occupied by each data type using sys. getsizeof ().
# Check:
# int float bool string list tuple dictionary set
# 6. Take a person's age and calculate how many days they have lived (assume 365 days/year).
# 7. Convert total seconds into:
# Hours
# Minutes
# Seconds
# Example:
# Input:
# 3675
# Output:
# 1 Hour
# 1 Minute
# 15 Seconds
# 8. Take a four-digit number and calculate: Sum of all digits
# Addition
# Subtraction
# Multiplication
# Division
# Floor Division
# Modulus
# Exponent
# Square of first number
# Cube of second number9. Build a Scientific Calculator that accepts two numbers and displays:
#
# Square root of both numbers (using **0.5)
