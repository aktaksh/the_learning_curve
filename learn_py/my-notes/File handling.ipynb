# %%
#Filehandling 

file = open("common_task_table.csv", "r")
print(file)
print("filename:", file.name, file.mode)
file.close()
print(file.closed)

w
# Out:
# <_io.TextIOWrapper name='common_task_table.csv' mode='r' encoding='UTF-8'>
# filename: common_task_table.csv r
# True

# %%
with open(comm )
# Out:
# ['__annotate__',
#  '__annotations__',
#  '__builtins__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__getstate__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__type_params__',
#  '__wrapped__']
