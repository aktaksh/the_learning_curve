# %% [markdown]
# # take a list of fruits and search a specific fruits
# # find the sum of all numbers in a list
# # remove duplicates values from a list
# # replace every negative number in a list with 0
# # move all zeros to the end of the list.
# # find common elements between 2 lists
# # reverse a list using loop

# %%
fruits = ["apple", "banana" , "orange"]
for frt in fruits:
    if frt == "apple":
        print (frt)
    else:
        print(f"fruit is not apple, it is {frt}")
if "orange" in fruits:
    print("yes present apple")
# Out:
# apple
# fruit is not apple, it is banana
# fruit is not apple, it is orange
# yes present apple

# %%
list1 = [x ** 2 for x in range(6)]
print(list(list1))
for sum in list1:
    sum += sum
    print(f"{sum} in this iter")
# Out:
# [0, 1, 4, 9, 16, 25]
# 0 in this iter
# 2 in this iter
# 8 in this iter
# 18 in this iter
# 32 in this iter
# 50 in this iter

# %%
lis1 = [1,1,3,3,2,2,4]
for rep in lis1:
    if

# %%
# replace every negative number in a list with 0
lis1 = [1,1,3,3,2,0,-92,4]

for i in range(len(lis1)):
    if lis1[i] < 0 :
        #lis1.insert(i, 0)
        lis1[i] = 0
        print(lis1)
# Out:
# [1, 1, 3, 3, 2, 0, 0, 4]

# %%
lis1 = [1,1,3,3,2,0,-92,4]
lis1.remove(0)
print(lis1)
# Out:
# [1, 1, 3, 3, 2, -92, 4]

# %%
lis1 = [1,1,3,3,2,0,-92,0,4]
for i in lis1: 
    if i == 0:
        print(lis1)
# Out:
# [1, 1, 3, 3, 2, 0, -92, 0, 4]
# [1, 1, 3, 3, 2, 0, -92, 0, 4]

# %%
lis1 = [1,1,3,3,2,0,-92,0,4]
for i in range(len(lis1)):
    if lis1[i] == 0:
        lis1.append(0)
        lis1.remove(lis1[i])
        print(lis1)
# Out:
# [1, 1, 3, 3, 2, -92, 0, 4, 0]
# [1, 1, 3, 3, 2, -92, 4, 0, 0]
# [1, 1, 3, 3, 2, -92, 4, 0, 0]
# [1, 1, 3, 3, 2, -92, 4, 0, 0]

# %%
lis1 = [1,1,3,3,2,0,-92,4]
lis2 = [1,2,3,5,2,0,-92,3]
lis3 = []
if len(lis1) >= len(lis2):
    print(len(lis1))
for i in range(len(lis1)):
    if lis1[i] in lis2:
        lis3.append(lis1[i])
        print(lis3)
print(f"final : {lis3}")

set4 = set(lis3)
print(set4)

print(set4[1:3])
# Out:
# 8
# [1]
# [1, 1]
# [1, 1, 3]
# [1, 1, 3, 3]
# [1, 1, 3, 3, 2]
# [1, 1, 3, 3, 2, 0]
# [1, 1, 3, 3, 2, 0, -92]
# final : [1, 1, 3, 3, 2, 0, -92]
# {0, 1, 2, 3, -92}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 15
#      11
#      12 set4 = set(lis3)
#      13 print(set4)
#      14
# ---> 15 print(set4[1:3])
#      16
#      17
#      18
#
# TypeError: 'set' object is not subscriptable
