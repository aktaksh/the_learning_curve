# %%
num = 20 
NUM = 21
print(id(num),id(NUM))
# Out:
# 4321076488 4321076520

# %%
list1 = [1,2,3]
print(id(list1))
# Out:
# 4440502976

# %%
import keyword # should never use this 
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# Each class is datatype and vice versa

# %%
num1 = input("enetr number")
num2 = input("enetr number")

print(num,type(num))
print(num1 + num2) # will conacatenate strings and not the values coz dfeult ia streing

num3 = int(input("Enter no:")) # now with int it becomes the value as integer

# %%
num4 = int("4") #  converts value to integer , will not accept string
print(type(num4))

# %%
num1 = 9
num2 = 3
print(num//2)
print()

# %%
#TASKS

'''
can be combination of alphanumeric  or underscore(_)
Shouls not start with digits
Keywords cannot be used as Identifiers.
'''

# %%
num_34 = 23
_num23 = 34
#2num = 89 #error
'''num#7 = 76 #error'''
'''
num = 20
NUM = num+1
print(id(num),id(NUM))
l1 = [1,2,3]
l2 = [1,2,3]
print(id(l1),id(l2))
import keyword
print(keyword.kwlist)
#import = "John" #ERROR
'''
#Data types : int,float, list, dict, tuple more
'''
name = "John"
age = 43
is_Student = True
print(type(name),type(age),type(is_Student))
# input from user
name = input("Enter name: ")
print(name)
print(type(name))
num1 = input("Enter Number: ")
print(num1,type(num1))
num2 = input("Enter number 2")
print(num1 + num2)
#TYPE CONVERSION - int(), float(),list(),bool(),short(),byte(),tuple(),dict(),set()....
num1 = int(input("Enter Number1: "))
num2= int(input("Enter Number2: "))
print(num1+num2)
'''

# %%
num3 = int("3")
print(type(num3))
#num4 = int("xy") #ERROR
num1 = float(input("Enter Number1: "))
num2= float(input("Enter Number2: "))
print(num1+num2)'''
#OPERATORS - ARITHMETIC OPERATOR(+,-,*,/(float),//(floor),%(modulous),**(exponent))
num1 = 9
# num2=  2
# print(num1+num2)
# print(num1-num2)
# print(num1*num2)
# print(num1/num2)
# print(num1//num2)
# print(num1%num2) #remainder
# print(num1**2) #power
# Out:
#   Cell In[1], line 6
#     print(num1+num2)'''
#                     ^
# SyntaxError: incomplete input
